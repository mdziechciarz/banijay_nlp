# %%
import pandas as pd

# %%
# Define the sentences and their corresponding emotions
data = {
    "sentence": [
        "I can't believe they cancelled my flight without any notice!",
        "It's infuriating when people don't listen to simple instructions.",
        "How dare they blame me for their own mistake!",
        "The level of incompetence in this office is just astounding!",
        "Every time I see the mess, it just makes my blood boil.",
        "I'm sick and tired of being taken for granted.",
        "It's like talking to a wall, absolutely infuriating!",
        "They promised it would be done today, and yet here we are.",
        "Why is it so hard for them to keep their word?",
        "The audacity to lie straight to my face is just unbelievable.",
        "I've had it with their lack of responsibility.",
        "Watching them ignore the issue just makes me see red.",
        "I cannot stand the noise anymore; it's driving me insane!",
        "Their lack of empathy is just maddening.",
        "How could they just forget something so important?",
        "The disrespect shown was just the last straw for me.",
        "I'm at my wit's end with their constant delays.",
        "The injustice of the situation just makes my stomach turn.",
        "I was fuming when I found out what they had done.",
        "To be treated this way is completely unacceptable.",
        "Their negligence is just infuriating beyond words.",
        "I can't keep calm when they keep making the same mistakes.",
        "The way they brushed off my concerns was just insulting.",
        "It's exasperating trying to get a straight answer out of them.",
        "Their refusal to acknowledge the problem is just infuriating.",
        "I'm beyond angry with their lack of communication.",
        "Every excuse they give just adds fuel to the fire.",
        "The fact that they didn't apologize just makes it worse.",
        "I'm livid about the way they handled the situation.",
        "Their indifference to my feelings is just infuriating.",
        "I can't believe they would be so thoughtless.",
        "It's enraging how they pretend nothing happened.",
        "The way they dismissed my input was just infuriating.",
        "I'm seething with anger over their incompetence.",
        "Their failure to act in time just makes me furious.",
        "It's outrageous that they expect me to accept this.",
        "I'm fuming over the lack of respect they showed.",
        "The sheer audacity of their actions is just infuriating.",
        "I'm enraged by their selfishness and lack of consideration.",
        "How they managed to ruin everything is beyond me.",
        "Their apathy towards the situation is just maddening.",
        "I can't contain my anger when I think about what they did.",
        "The nerve of some people just leaves me seething.",
        "I'm infuriated by their inability to admit their mistakes.",
        "Their constant excuses just make me angrier.",
        "I'm fuming at the thought of their carelessness.",
        "The disrespect I've endured is just unbearable.",
        "I'm boiling with rage over their false promises.",
        "It's infuriating how they've managed to dodge responsibility.",
        "Their lack of action in times of need is just despicable.",
        "I can't stand how they always play the victim.",
        "Their ignorance is just a slap in the face.",
        "I'm outraged by the way they've treated everyone.",
        "Their failure to communicate is just the tip of the iceberg.",
        "I'm livid that they've been so misleading.",
        "Their avoidance of the issue is just cowardly.",
        "I'm so angry I can hardly speak.",
        "The fact that they think they can get away with this is maddening.",
        "Their arrogance is just beyond infuriating.",
        "It's exasperating how they continue to ignore reality.",
        "The way they've handled this whole situation is a joke.",
        #"I can't believe they would be so inconsiderate!",
    ],
    "emotion": ["anger"] * 61
}

# Correct the mistake with the emotion list length to match the number of sentences
data["emotion"] = ["anger"] * len(data["sentence"])


# Create the DataFrame again
df_anger = pd.DataFrame(data)
df_anger
# Out:
#                                              sentence emotion
# 0   I can't believe they cancelled my flight witho...   anger
# 1   It's infuriating when people don't listen to s...   anger
# 2       How dare they blame me for their own mistake!   anger
# 3   The level of incompetence in this office is ju...   anger
# 4   Every time I see the mess, it just makes my bl...   anger
# ..                                                ...     ...
# 56                   I'm so angry I can hardly speak.   anger
# 57  The fact that they think they can get away wit...   anger
# 58        Their arrogance is just beyond infuriating.   anger
# 59  It's exasperating how they continue to ignore ...   anger
# 60  The way they've handled this whole situation i...   anger
#
# [61 rows x 2 columns]

# %%
# Define the sentences for the emotion of disgust
disgust_sentences = [
    "The sight of the spoiled food made me gag.",
    "I can't stand the smell in this room; it's revolting.",
    "The way they talk about others behind their backs is disgusting.",
    "I felt sick watching them waste so much food.",
    "The lack of hygiene in that place is utterly repulsive.",
    "Seeing the trash littered all over the beach was disheartening.",
    "I'm appalled by the blatant disrespect they showed.",
    "The greed and selfishness on display were sickening.",
    "It's disgusting how they can lie with such ease.",
    "The cruelty towards animals in those videos is horrifying.",
    "The state of the public restrooms was beyond disgusting.",
    "Witnessing their blatant disregard for others' feelings was disturbing.",
    "The corruption in the system makes my stomach turn.",
    "I'm disgusted by the pollution choking our rivers and lakes.",
    "The quality of the food served was abominable.",
    "Hearing their prejudiced remarks was just appalling.",
    "The level of deceit and manipulation involved is nauseating.",
    "It's revolting how they exploit vulnerabilities for profit.",
    "The misuse of power for personal gain is utterly despicable.",
    "I find their lack of empathy towards the less fortunate disgusting.",
    "The conditions in which they keep these animals are horrific.",
    "Seeing the exploitation of the environment for greed is sickening.",
    "Their hypocritical behavior is just too repulsive.",
    "The amount of waste produced is just shocking and disgusting.",
    "The neglect shown towards the needy is deeply disturbing.",
    "Their attitude towards cleanliness is just repugnant.",
    "I'm disgusted by the way they treat their employees.",
    "The exploitation in those factories is abhorrent.",
    "Their manipulative tactics make me sick.",
    "Witnessing their indifference towards injustice is appalling.",
    "The selfishness of hoarding resources is despicable.",
    "I can't believe the levels of pollution they're responsible for.",
    "The disrespect for historical sites was just shameful.",
    "It's disgusting how they handle food with no care for hygiene.",
    "The mockery of serious issues is utterly disgraceful.",
    "Their dismissal of scientific evidence is repulsive.",
    "The betrayal of trust was simply loathsome.",
    "Their justification for unethical actions is nauseating.",
    "Seeing the lack of consideration for others' well-being was vile.",
    "The amount of litter left in public spaces is repulsive.",
    "Their disregard for community safety is disgusting.",
    "The exploitation of vulnerable communities is horrific.",
    "It's revolting to see them ignore pleas for help.",
    "Their willingness to spread lies is detestable.",
    "The damage they're doing to the ecosystem is appalling.",
    "Witnessing their blatant greed is sickening.",
    "Their manipulation of facts is just disgusting.",
    "The way they've ruined the landscape is atrocious.",
    "It's abhorrent how they treat people like numbers.",
    "Their tasteless jokes about serious matters are despicable.",
    #"Seeing the joy they take in others' misfortune is disgusting.",
    "Their casual racism is deeply disturbing.",
    "It's revolting how they profit off others' tragedies.",
    "Their indifference to suffering is sickening.",
    "The way they discard relationships is chilling.",
    "Their exploitation of trust is just vile.",
    "The normalization of such behavior is disgusting.",
    "Their disregard for future generations is despicable.",
    "His unkempt appearance, greasy hair, and stained clothes filled me with an intense sense of repulsion.",
    "The taste of the spoiled milk was so foul that I immediately spat it out, feeling a wave of disgust wash over me.",
    "The putrid smell emanating from the decaying garbage made my stomach churn.",
    "The sight of the cockroaches scurrying across the kitchen floor filled me with revulsion.",
]

# Create the DataFrame for disgust
disgust_data = {
    "sentence": disgust_sentences,
    "emotion": ["disgust"] * len(disgust_sentences)
}

df_disgust = pd.DataFrame(disgust_data)

df_disgust
# Out:
#                                              sentence  emotion
# 0          The sight of the spoiled food made me gag.  disgust
# 1   I can't stand the smell in this room; it's rev...  disgust
# 2   The way they talk about others behind their ba...  disgust
# 3       I felt sick watching them waste so much food.  disgust
# 4   The lack of hygiene in that place is utterly r...  disgust
# ..                                                ...      ...
# 56  Their disregard for future generations is desp...  disgust
# 57  His unkempt appearance, greasy hair, and stain...  disgust
# 58  The taste of the spoiled milk was so foul that...  disgust
# 59  The putrid smell emanating from the decaying g...  disgust
# 60  The sight of the cockroaches scurrying across ...  disgust
#
# [61 rows x 2 columns]

# %%
# Define the sentences for the emotion of fear
fear_sentences = [
    "I'm terrified that I might lose my job in these uncertain times.",
    "The thought of being alone in the dark fills me with dread.",
    "Hearing strange noises at night when I'm alone is frightening.",
    "I'm scared of heights, and just looking down makes me feel dizzy.",
    "The idea of speaking in front of a crowd makes my stomach churn.",
    "I fear for the safety of my loved ones in such a volatile world.",
    "Watching the news these days is just an exercise in anxiety.",
    "I'm petrified of the thought that I might never achieve my dreams.",
    "The possibility of failing the exam has been haunting me for weeks.",
    "I'm always afraid that I'll say the wrong thing and upset someone.",
    "The uncertainty of the future is a constant source of fear for me.",
    "I'm terrified of the thought of losing someone close to me.",
    "The rapid changes in the world make me feel uneasy and scared.",
    "I'm scared of making decisions that I might regret later.",
    "The thought of being judged by others is always looming over me.",
    "I fear that my health issues might get worse over time.",
    "The darkness has always filled me with an irrational sense of fear.",
    "I'm scared of the deep sea and what might be lurking beneath.",
    "The stories of people going missing in the woods are chilling.",
    "I'm afraid of being in crowded places; it makes me feel trapped.",
    "The thought of getting lost in a foreign country is terrifying.",
    "I'm fearful of the impact of climate change on our planet.",
    "The possibility of a loved one getting sick is a constant worry.",
    "I'm terrified of bugs; even a small spider can make me panic.",
    "The thought of ghosts and supernatural beings scares me at night.",
    "I'm afraid of rejection and not being accepted by others.",
    "The prospect of growing old and being alone is a scary thought.",
    "I fear that my personal information online might be stolen.",
    "The idea of a global pandemic has become a real and present fear.",
    "I'm scared of losing my memories and not remembering loved ones.",
    "The fear of failure in my career keeps me up at night.",
    "I'm terrified of the thought of being involved in a car accident.",
    "The idea of not being able to breathe underwater is horrifying.",
    "I fear that my actions may inadvertently hurt someone I care about.",
    "The thought of war and conflict in the world is deeply unsettling.",
    "I'm scared that I won't be able to protect my family in danger.",
    "The unpredictability of natural disasters is a source of fear.",
    "I'm fearful of the judgment and criticism of others.",
    "The idea of losing my identity and sense of self is terrifying.",
    "I'm afraid of the dark because of the unknown dangers it may hold.",
    "The thought of being trapped in an elevator is panic-inducing.",
    "I fear the consequences of making a major life mistake.",
    "The possibility of not being able to achieve my goals is frightening.",
    "I'm scared of animals that I'm not familiar with.",
    "The fear of being forgotten or ignored by friends is heartbreaking.",
    "I'm terrified by the increasing incidents of cyber attacks.",
    "The idea of a loved one suffering in any way is unbearable.",
    "I'm scared of the societal pressure to conform and lose my individuality.",
    "The thought of a sudden illness or accident is always a worry.",
    "I fear not being good enough and constantly compare myself to others.",
    "The unpredictability of life and not knowing what's next is scary.",
    "I'm afraid of the dark web and the dangers it poses.",
    "The fear of being alone and isolated is a constant companion.",
    "I'm terrified of death, both for myself and those I love.",
    "The idea of being buried alive is a nightmare I can't shake.",
    "I fear the unknown and what it might bring.",
    "The thought of losing my job and financial security is terrifying.",
    "I'm scared of the dark because of the shadows and what they conceal.",
    "The fear of being judged for my beliefs keeps me up at night.",
    "Whispers in the attic chilled my spine",
    "The sound of footsteps behind me sends shivers down my back"
]

# Create the DataFrame for fear
fear_data = {
    "sentence": fear_sentences,
    "emotion": ["fear"] * len(fear_sentences)
}

df_fear = pd.DataFrame(fear_data)

df_fear
# Out:
#                                              sentence emotion
# 0   I'm terrified that I might lose my job in thes...    fear
# 1   The thought of being alone in the dark fills m...    fear
# 2   Hearing strange noises at night when I'm alone...    fear
# 3   I'm scared of heights, and just looking down m...    fear
# 4   The idea of speaking in front of a crowd makes...    fear
# ..                                                ...     ...
# 56  The thought of losing my job and financial sec...    fear
# 57  I'm scared of the dark because of the shadows ...    fear
# 58  The fear of being judged for my beliefs keeps ...    fear
# 59             Whispers in the attic chilled my spine    fear
# 60  The sound of footsteps behind me sends shivers...    fear
#
# [61 rows x 2 columns]

# %%
# Define the sentences for the emotion of happiness
happiness_sentences = [
    "Seeing the smile on her face made my day.",
    "I felt a burst of joy when I got the job offer.",
    "Spending time with my family over the holidays fills me with happiness.",
    "The laughter of my friends is contagious; it always lifts my spirits.",
    "I'm so grateful for the support of my loved ones; it makes me truly happy.",
    "The beauty of the sunrise fills me with a sense of wonder and joy.",
    "Receiving unexpected kindness from a stranger was a heartwarming moment.",
    "The excitement of starting a new project is exhilarating.",
    "Feeling the warmth of the sun on my skin is a simple pleasure that brings me joy.",
    "The thrill of traveling to a new place is unmatched.",
    "I'm overjoyed at the thought of reuniting with old friends.",
    "Achieving my fitness goals has been incredibly satisfying and uplifting.",
    "Finding a book that I can't put down fills me with joy.",
    "Cooking my favorite meal and sharing it with others is a source of happiness.",
    "The sense of accomplishment after a hard day's work is deeply gratifying.",
    "Laughing till my stomach hurts is the best kind of therapy.",
    "The feeling of the cool breeze on a hot day is so refreshing.",
    "Watching my favorite movie always puts me in a good mood.",
    "The satisfaction of solving a challenging problem is exhilarating.",
    "Feeling healthy and energetic makes me appreciate life more.",
    "The joy of learning something new is a feeling I treasure.",
    "Seeing my plants grow and thrive fills me with pride and happiness.",
    "The anticipation of a well-deserved vacation is thrilling.",
    "Receiving praise for my work is incredibly motivating.",
    "The peace and tranquility of a quiet morning is blissful.",
    "Dancing to my favorite music is an instant mood booster.",
    "The happiness of giving and helping others is incomparable.",
    "The excitement of achieving a personal milestone is overwhelming.",
    "Experiencing the beauty of nature is always uplifting.",
    "The pleasure of a good conversation with a friend is priceless.",
    "The contentment of a cozy night in is unmatched.",
    "Witnessing acts of kindness restores my faith in humanity and brings me joy.",
    "The fulfillment of contributing to a cause I believe in is rewarding.",
    "Celebrating small victories in life keeps me positive and happy.",
    "The delight of indulging in my favorite dessert is a simple joy.",
    "The bliss of a quiet evening with a good book is my ideal happiness.",
    "The exhilaration of a surprise party thrown for me was unforgettable.",
    "Feeling connected with someone on a deep level is a source of great happiness.",
    "The joy of a clean and organized space is surprisingly satisfying.",
    "The happiness of being in love is indescribable.",
    "Seeing the success of my hard work is incredibly fulfilling.",
    "The joy of a peaceful walk in the park is a cherished moment.",
    "The thrill of learning a new skill is both challenging and rewarding.",
    "The comfort of a warm hug from a loved one is irreplaceable.",
    "The excitement of discovering a new hobby is invigorating.",
    "The pleasure of a sunny day after a week of rain is refreshing.",
    "The satisfaction of helping someone in need is deeply fulfilling.",
    "The delight in receiving a heartfelt compliment is a boost to my spirits.",
    "The bliss of a well-spent day with loved ones is the essence of happiness.",
    "The joy of finally understanding a complex concept is immensely satisfying.",
    "The happiness that comes from a simple life is profound.",
    "The contentment of savoring a moment of peace is precious.",
    "The exhilaration of a successful teamwork effort is inspiring.",
    "The joy of a heartfelt laughter shared with friends is priceless.",
    "The satisfaction of a productive day is a great feeling.",
    "The happiness of being true to oneself is the key to contentment.",
    "Sunlight danced through the leaves, filling the garden with warmth and joy.",
    "The sound of children's laughter filled the air with happiness and innocence.",
    "The sight of the colorful balloons floating in the sky brought joy to everyone's hearts.",
    "Balloons soared, their vibrant colors lifting spirits at the birthday party.",
    #"The smell of freshly baked cookies filled the house with warmth and happiness.",
    "The taste of the homemade apple pie was a delightful treat for the taste buds."
]

# Create the DataFrame for happiness
happiness_data = {
    "sentence": happiness_sentences,
    "emotion": ["happiness"] * len(happiness_sentences)
}

df_happiness = pd.DataFrame(happiness_data)

df_happiness
# Out:
#                                              sentence    emotion
# 0           Seeing the smile on her face made my day.  happiness
# 1     I felt a burst of joy when I got the job offer.  happiness
# 2   Spending time with my family over the holidays...  happiness
# 3   The laughter of my friends is contagious; it a...  happiness
# 4   I'm so grateful for the support of my loved on...  happiness
# ..                                                ...        ...
# 56  Sunlight danced through the leaves, filling th...  happiness
# 57  The sound of children's laughter filled the ai...  happiness
# 58  The sight of the colorful balloons floating in...  happiness
# 59  Balloons soared, their vibrant colors lifting ...  happiness
# 60  The taste of the homemade apple pie was a deli...  happiness
#
# [61 rows x 2 columns]

# %%
# Define the sentences for the emotion of sadness
sadness_sentences = [
    "The news of her passing left a void in my heart.",
    "Losing my job unexpectedly has been incredibly hard to accept.",
    "The end of a long-term relationship left me feeling lost and alone.",
    "Seeing the suffering in the world often overwhelms me with sadness.",
    "The anniversary of the loss brings back painful memories.",
    "Feeling misunderstood by those I care about is deeply disheartening.",
    "The realization that some friendships were not meant to last is saddening.",
    "Missing out on important family moments makes me feel regretful and sad.",
    "The fading of cherished memories over time is a source of melancholy.",
    "Not being able to help a friend in need has left me feeling helpless.",
    "The struggle with my own thoughts and anxieties is often isolating.",
    "Witnessing the decline of a loved one's health is heart-wrenching.",
    "The harshness of the world towards the vulnerable fills me with sorrow.",
    "Feeling like I'm not living up to my potential is demoralizing.",
    "The loss of a pet who was like family is profoundly sad.",
    "The destruction of nature and wildlife habitats is deeply troubling.",
    "Seeing people in pain or distress without being able to ease their suffering is hard.",
    "The loneliness of being far from loved ones is a constant ache.",
    "Realizing that things will never be the same again is a bitter pill to swallow.",
    "The disappointment of unmet expectations can be crushing.",
    "Struggling to find meaning in difficult times is a lonely journey.",
    "The impact of harsh words can linger and deepen the sadness.",
    "Feeling excluded or left out by peers is a hurtful experience.",
    "The guilt of past mistakes and missed opportunities can be haunting.",
    "Witnessing the end of an era or the closing of a chapter in life is melancholic.",
    "The sorrow of saying goodbye to a cherished place is hard to describe.",
    "The emptiness after a project or goal is completed can feel surprisingly hollow.",
    "Seeing the disparity between the haves and the have-nots is disheartening.",
    "The fear of losing someone close creates a shadow of sadness.",
    "Feeling powerless in the face of global issues is frustrating and saddening.",
    "The quiet that follows a heated argument can be filled with regret and sorrow.",
    "The slow fading of passion or enthusiasm in a hobby or interest is disheartening.",
    "Realizing that you've grown apart from someone you used to be close with is sad.",
    "The pain of being misunderstood or judged unfairly is difficult to bear.",
    "Struggling to express how you truly feel can lead to a deep sense of isolation.",
    "The disappointment in seeing a loved one make harmful choices is heart-breaking.",
    "Feeling unappreciated or taken for granted can diminish joy and bring sadness.",
    "The realization that time is passing by quickly and moments are fleeting is sobering.",
    "The melancholy of rainy days can sometimes mirror inner feelings of sadness.",
    "Feeling stuck in a routine or life phase without clear direction is dispiriting.",
    "The grief of losing a dream or ambition to unforeseen circumstances is tough.",
    "The sting of rejection, whether in love, work, or friendship, can be long-lasting.",
    "Witnessing the loss of cultural or historical landmarks is a unique sadness.",
    "The discomfort of being in a place where you no longer feel you belong is distressing.",
    "The sinking feeling when you realize a mistake cannot be undone is heavy.",
    "The void left by a period of happiness that has ended can be hard to fill.",
    "Feeling like an outsider in situations where you used to feel comfortable is jarring.",
    "The abrupt end to a journey or experience that was once fulfilling is hard to accept.",
    "The slow realization that some goals may remain unattainable is disheartening.",

    "The sadness in moments of reflection on what could have been is poignant.",
    "Realizing that some bonds may never be repaired or reclaimed is a silent grief.",
    "The quiet moments alone now feel heavier, filled with echoes of the past.",
    "The fading light of dusk mirrors the dimming joy in my heart.",
    "Each passing day without their presence feels like a chapter left unfinished.",
    "The melody of our song now plays as a somber symphony of solitude.",
    "The starkness of an empty chair at the table is a silent testament to loss.",
    "The shadows cast by memories make the present seem less vivid.",
    "Holding onto a piece of clothing, still carrying their scent, is bittersweet.",
    "The first snowfall without them turns the world cold and gray.",
    "Turning the page on a calendar, knowing they're not here to share the moments, is lonely.",
    "The unspoken words and unfulfilled promises linger like ghosts in the mind.",
]

# Create the DataFrame for sadness
sadness_data = {
    "sentence": sadness_sentences,
    "emotion": ["sadness"] * len(sadness_sentences)
}

df_sadness = pd.DataFrame(sadness_data)

df_sadness
# Out:
#                                              sentence  emotion
# 0    The news of her passing left a void in my heart.  sadness
# 1   Losing my job unexpectedly has been incredibly...  sadness
# 2   The end of a long-term relationship left me fe...  sadness
# 3   Seeing the suffering in the world often overwh...  sadness
# 4   The anniversary of the loss brings back painfu...  sadness
# ..                                                ...      ...
# 56  The shadows cast by memories make the present ...  sadness
# 57  Holding onto a piece of clothing, still carryi...  sadness
# 58  The first snowfall without them turns the worl...  sadness
# 59  Turning the page on a calendar, knowing they'r...  sadness
# 60  The unspoken words and unfulfilled promises li...  sadness
#
# [61 rows x 2 columns]

# %%
# Define the sentences for the emotion of disgust, completing the list to 60 sentences
complete_disgust_sentences = [
    "The sight of the spoiled food made me gag.",
    "I can't stand the smell in this room; it's revolting.",
    "The way they talk about others behind their backs is disgusting.",
    "I felt sick watching them waste so much food.",
    "The lack of hygiene in that place is utterly repulsive.",
    "Seeing the trash littered all over the beach was disheartening.",
    "I'm appalled by the blatant disrespect they showed.",
    "The greed and selfishness on display were sickening.",
    "It's disgusting how they can lie with such ease.",
    "The cruelty towards animals in those videos is horrifying.",
    "The state of the public restrooms was beyond disgusting.",
    "Witnessing their blatant disregard for others' feelings was disturbing.",
    "The corruption in the system makes my stomach turn.",
    "I'm disgusted by the pollution choking our rivers and lakes.",
    "The quality of the food served was abominable.",
    "Hearing their prejudiced remarks was just appalling.",
    "The level of deceit and manipulation involved is nauseating.",
    "It's revolting how they exploit vulnerabilities for profit.",
    "The misuse of power for personal gain is utterly despicable.",
    "I find their lack of empathy towards the less fortunate disgusting.",
    "The conditions in which they keep these animals are horrific.",
    "Seeing the exploitation of the environment for greed is sickening.",
    "Their hypocritical behavior is just too repulsive.",
    "The amount of waste produced is just shocking and disgusting.",
    "The neglect shown towards the needy is deeply disturbing.",
    "Their attitude towards cleanliness is just repugnant.",
    "I'm disgusted by the way they treat their employees.",
    "The exploitation in those factories is abhorrent.",
    "Their manipulative tactics make me sick.",
    "Witnessing their indifference towards injustice is appalling.",
    "The selfishness of hoarding resources is despicable.",
    "I can't believe the levels of pollution they're responsible for.",
    "The disrespect for historical sites was just shameful.",
    "It's disgusting how they handle food with no care for hygiene.",
    "The mockery of serious issues is utterly disgraceful.",
    "Their dismissal of scientific evidence is repulsive.",
    "The betrayal of trust was simply loathsome.",
    "Their justification for unethical actions is nauseating.",
    "Seeing the lack of consideration for others' well-being was vile.",
    "The amount of litter left in public spaces is repulsive.",
    "Their disregard for community safety is disgusting.",
    "The exploitation of vulnerable communities is horrific.",
    "It's revolting to see them ignore pleas for help.",
    "Their willingness to spread lies is detestable.",
    "The damage they're doing to the ecosystem is appalling.",
    "Witnessing their blatant greed is sickening.",
    "Their manipulation of facts is just disgusting.",
    "The way they've ruined the landscape is atrocious.",
    "It's abhorrent how they treat people like numbers.",
    "Their tasteless jokes about serious matters are despicable.",
    "Seeing the joy they take in others' misfortune is disgusting.",
    "Their casual racism is deeply disturbing.",
    "It's revolting how they profit off others' tragedies.",
    "Their indifference to suffering is sickening.",
    "The way they discard relationships is chilling.",
    "Their exploitation of trust is just vile.",
    "The normalization of such behavior is disgusting.",
    "Their disregard for future generations is despicable.",
    "Watching them dismiss crucial issues for personal gain is loathsome.",
    "Their pleasure in others' failures is utterly despicable.",
    "The blatant disregard for ethical standards in their work is appalling."
]

# Create the DataFrame for the complete list of disgust sentences
complete_disgust_data = {
    "sentence": complete_disgust_sentences,
    "emotion": ["disgust"] * len(complete_disgust_sentences)
}

df_complete_disgust = pd.DataFrame(complete_disgust_data)

df_complete_disgust
# Out:
#                                              sentence  emotion
# 0          The sight of the spoiled food made me gag.  disgust
# 1   I can't stand the smell in this room; it's rev...  disgust
# 2   The way they talk about others behind their ba...  disgust
# 3       I felt sick watching them waste so much food.  disgust
# 4   The lack of hygiene in that place is utterly r...  disgust
# ..                                                ...      ...
# 56  The normalization of such behavior is disgusting.  disgust
# 57  Their disregard for future generations is desp...  disgust
# 58  Watching them dismiss crucial issues for perso...  disgust
# 59  Their pleasure in others' failures is utterly ...  disgust
# 60  The blatant disregard for ethical standards in...  disgust
#
# [61 rows x 2 columns]

# %%
# Now, let's concatenate all these DataFrames into one
df_all_emotions = pd.concat([df_anger, df_complete_disgust, df_fear, df_happiness, df_sadness])

# %%
df_all_emotions.value_counts('emotion')
# Out:
# emotion
# anger        61
# disgust      61
# fear         61
# happiness    61
# sadness      61
# Name: count, dtype: int64

# %%
df_all_emotions.to_csv("gpt_60_emotions.csv", index=False)
