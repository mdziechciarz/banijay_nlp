# %% [markdown]
# ## Importing important libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.sequence import pad_sequences
from transformers import RobertaTokenizer
import numpy as np
from transformers import TFRobertaForSequenceClassification, RobertaConfig
import tensorflow as tf
import tensorflow.keras.backend as K
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import os
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# 2024-04-05 06:52:32.471980: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-05 06:52:32.472022: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-05 06:52:32.473186: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-05 06:52:32.479772: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Hyperparameters
#
# Easy and straightforward hyperparameter tuning

# %%
# Hyperparameters
BATCH_SIZE = 16
LEARNING_RATE = 2e-5
EPOCHS = 30
TEST_SIZE = 0.2
RANDOM_STATE = 42
MAX_LEN = 128  # Maximum sequence length
NUM_LABELS = 6
RANDOM_STATE = 42
# Define the base path for saving model information
base_save_path = "Large_final_checkpoints"
checkpoint_path = "Large_final_checkpoints/cp-{epoch:04d}.ckpt"

# %% [markdown]
# ## F1 Metric and tokenizer function

# %%
def f1_metric(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## Setup and Data Preparation
#
# Loading the dataset, preprocessing the text, and preparing the data for the model.

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = 'final_concatenated.csv'

# Load the dataset and drop duplicates
dataset = pd.read_csv(file_path).drop_duplicates(subset=['sentence'])

# Drop rows with missing values in the 'emotion' column and filter out 'neutral' emotions
dataset = dataset.dropna(subset=['emotion']).query("emotion != 'neutral'")

# Replace any labels not in the specified list with NaN
valid_labels = ['happiness', 'disgust', 'sadness', 'fear', 'anger', 'surprise']
dataset['emotion'] = dataset['emotion'].apply(lambda x: x if x in valid_labels else pd.NA)

# Map any duplicate labels to one of the specified labels
label_mapping = {
    'happiness': 'happiness',  # Merge 'joy' into 'happiness'
    'disgust': 'disgust',  # Merge 'disgustt' into 'disgust'
    'joy': 'happiness'
    # You can add more mappings if needed
}

dataset['emotion'] = dataset['emotion'].map(label_mapping).fillna(dataset['emotion'])

# Drop rows where emotion is NaN (if any)
dataset = dataset.dropna(subset=['emotion'])

# Shuffle the combined dataset
data = dataset.sample(frac=1).reset_index(drop=True)

# Display basic information about the combined dataset
print("Preview of the dataset:")
print(data.head())

print("\nSummary statistics of the dataset:")
print(data.describe())

print("\nInformation about columns in the dataset:")
print(data.info())

# Extract sentences and labels
sentences = data['sentence'].values
labels = data['emotion'].values

# Print the unique labels in the 'emotion' column
unique_labels = data['emotion'].unique()
print("\nUnique labels in the 'emotion' column:")
for label in unique_labels:
    print(label)
# Out:
# Preview of the dataset:
#                                             sentence    emotion
# 0  All this was very sad for the poor little duck...    sadness
# 1        My friend is sad about the loss of her cat.    sadness
# 2            yes, please do I'm worried about her D:       fear
# 3  Hearing strange noises outside my window gave ...       fear
# 4  Discovery group_A new book that piques my inte...  happiness
#
# Summary statistics of the dataset:
#                                                  sentence emotion
# count                                              132831  132831
# unique                                             132831       6
# top     All this was very sad for the poor little duck...   anger
# freq                                                    1   28864
#
# Information about columns in the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132831 entries, 0 to 132830
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   sentence  132831 non-null  object
#  1   emotion   132831 non-null  object
# dtypes: object(2)
# memory usage: 2.0+ MB
# None
#
# Unique labels in the 'emotion' column:
# sadness
# fear
# happiness
# anger
# disgust
# surprise

# %%
# Encode the labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
labels = tf.convert_to_tensor(labels)
# Out:
# 2024-04-05 06:52:37.200280: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-04-05 06:52:37.200592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15410 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:e1:00.0, compute capability: 8.6

# %%
# Initialize tokenizer
tokenizer = RobertaTokenizer.from_pretrained('roberta-large')

# Assuming `sentences` is your dataset and `labels` are your labels
max_len = MAX_LEN  # Define the maximum length
input_ids = []
attention_masks = []

# Tokenize all sentences
for sent in sentences:
    encoded_dict = tokenizer.encode_plus(
                        sent,
                        add_special_tokens=True,
                        max_length=max_len,
                        truncation=True,
                        padding='max_length',
                        return_attention_mask=True,
                        return_tensors='tf',
                   )
    input_ids.append(tf.squeeze(encoded_dict['input_ids']))
    attention_masks.append(tf.squeeze(encoded_dict['attention_mask']))

# Convert lists to NumPy arrays instead of TensorFlow tensors
input_ids = tf.stack(input_ids).numpy()
attention_masks = tf.stack(attention_masks).numpy()
labels = np.array(labels)  # Assuming labels are in a suitable format

# Split the data into training and validation sets
input_ids_train, input_ids_val, attention_masks_train, attention_masks_val, labels_train, labels_val = train_test_split(
    input_ids, attention_masks, labels, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=labels)

# Optionally convert NumPy arrays back to TensorFlow tensors
input_ids_train = tf.constant(input_ids_train)
input_ids_val = tf.constant(input_ids_val)
attention_masks_train = tf.constant(attention_masks_train)
attention_masks_val = tf.constant(attention_masks_val)
labels_train = tf.constant(labels_train)
labels_val = tf.constant(labels_val)

# %%
# Create TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((
    {
        'input_ids': input_ids_train,
        'attention_mask': attention_masks_train
    },
    labels_train
))

val_dataset = tf.data.Dataset.from_tensor_slices((
    {
        'input_ids': input_ids_val,
        'attention_mask': attention_masks_val
    },
    labels_val
))

# %%
# Apply caching and prefetching
train_dataset = train_dataset.cache().shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Model training
#
# Setting up the RoBERTa model, defining the training loop, and initiating the training process.

# %%
# Load RoBERTa model
model_config = RobertaConfig.from_pretrained('roberta-large', num_labels=NUM_LABELS)
model = TFRobertaForSequenceClassification.from_pretrained('roberta-large', config=model_config)
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy', f1_metric])
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Monitor validation accuracy
    patience=2,             # Number of epochs with no improvement after which training will be stopped
    verbose=1,              # Log when training is stopped
    restore_best_weights=True, # Restore model weights from the epoch with the best value of the monitored quantity
    mode='min'
)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,  # Reduction factor for the learning rate
    patience=1,  # Number of epochs with no improvement after which learning rate will be reduced
    verbose=1
)

# %%
# Fit label encoder and return encoded labels
labels_encoded = label_encoder.fit_transform(labels)

# %%
# Count the number of occurrences of each class
class_counts = np.unique(labels_encoded, return_counts=True)[1]

# Calculate total number of samples
total_samples = len(labels_encoded)

# Calculate class weights inversely proportional to the class frequencies
class_weights = {i: total_samples/(count * len(class_counts)) for i, count in enumerate(class_counts)}

# %%
# Specify the directory where you want to save the checkpoints
checkpoint_dir = os.path.dirname(checkpoint_path)

# Ensure the directory exists. If it doesn't, create it.
os.makedirs(base_save_path, exist_ok=True)

# Specify the checkpoint file path pattern
checkpoint_path = os.path.join(base_save_path, "cp-{epoch:04d}.ckpt")
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a ModelCheckpoint callback
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True, 
    save_best_only=True,  # Saves only the best model
    monitor='val_loss',  # Monitoring validation loss to determine the best model
    mode='min',  # Since we're monitoring 'val_loss', 'min' mode saves the model when the metric has decreased
    save_freq='epoch')  # Saving the model after each epoch

# %%
# Fit the model with class weights, early stopping, and learning rate scheduler
history = model.fit(
    train_dataset,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[early_stopping, lr_scheduler, cp_callback],
    class_weight=class_weights  # Use the calculated class weights
)
# Out:
# Epoch 1/30
# 2024-04-05 06:54:59.432229: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f5a85133280 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-05 06:54:59.432291: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-04-05 06:54:59.441634: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-04-05 06:54:59.473224: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712300099.573554  407925 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6642/6642 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.8709 - f1_metric: 1.1802
# Epoch 1: val_loss improved from inf to 0.22230, saving model to Large_final_checkpoints/cp-0001.ckpt
# 6642/6642 [==============================] - 2927s 427ms/step - loss: 0.3819 - accuracy: 0.8709 - f1_metric: 1.1802 - val_loss: 0.2223 - val_accuracy: 0.9235 - val_f1_metric: 1.0677 - lr: 2.0000e-05
# Epoch 2/30
# 6642/6642 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9285 - f1_metric: 1.0908
# Epoch 2: val_loss improved from 0.22230 to 0.21438, saving model to Large_final_checkpoints/cp-0002.ckpt
# 6642/6642 [==============================] - 2679s 403ms/step - loss: 0.2065 - accuracy: 0.9285 - f1_metric: 1.0908 - val_loss: 0.2144 - val_accuracy: 0.9307 - val_f1_metric: 1.0904 - lr: 2.0000e-05
# Epoch 3/30
# 6642/6642 [==============================] - ETA: 0s - loss: 0.1738 - accuracy: 0.9384 - f1_metric: 1.0871
# Epoch 3: val_loss improved from 0.21438 to 0.20482, saving model to Large_final_checkpoints/cp-0003.ckpt
# 6642/6642 [==============================] - 3468s 522ms/step - loss: 0.1738 - accuracy: 0.9384 - f1_metric: 1.0871 - val_loss: 0.2048 - val_accuracy: 0.9327 - val_f1_metric: 1.0575 - lr: 2.0000e-05
# Epoch 4/30
# 6642/6642 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9523 - f1_metric: 1.0641
# Epoch 4: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 4: val_loss did not improve from 0.20482
# 6642/6642 [==============================] - 4941s 744ms/step - loss: 0.1351 - accuracy: 0.9523 - f1_metric: 1.0641 - val_loss: 0.2153 - val_accuracy: 0.9292 - val_f1_metric: 1.0205 - lr: 2.0000e-05
# Epoch 5/30
# 6642/6642 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9729 - f1_metric: 0.9745Restoring model weights from the end of the best epoch: 3.
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 5: val_loss did not improve from 0.20482
# 6642/6642 [==============================] - 4785s 720ms/step - loss: 0.0732 - accuracy: 0.9729 - f1_metric: 0.9745 - val_loss: 0.2230 - val_accuracy: 0.9410 - val_f1_metric: 0.9649 - lr: 4.0000e-06
# Epoch 5: early stopping

# %%
results = model.evaluate(val_dataset)
print(f"Validation loss: {results[0]}, Validation accuracy: {results[1]}, Validation F1 Score: {results[2]}")
# Out:
# 1661/1661 [==============================] - 222s 134ms/step - loss: 0.2048 - accuracy: 0.9327 - f1_metric: 1.0575
# Validation loss: 0.20482145249843597, Validation accuracy: 0.9326608180999756, Validation F1 Score: 1.057465672492981

# %% [markdown]
# ## Visualization
#
# Generate usefull insights on the training

# %%
def plot_training_history(history):
    fig, ax = plt.subplots(1, 3, figsize=(20, 5))
    
    # Plot training & validation accuracy values
    ax[0].plot(history.history['accuracy'])
    ax[0].plot(history.history['val_accuracy'])
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    ax[1].plot(history.history['loss'])
    ax[1].plot(history.history['val_loss'])
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Val'], loc='upper left')
    
    # Plot training & validation F1 score values
    ax[2].plot(history.history['f1_metric'])
    ax[2].plot(history.history['val_f1_metric'])
    ax[2].set_title('Model F1 Score')
    ax[2].set_ylabel('F1 Score')
    ax[2].set_xlabel('Epoch')
    ax[2].legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history)

# %% [markdown]
# ##  Generate the Confusion Matrix and Metrics
#
# With the true labels and predictions, we can now generate a confusion matrix and calculate other evaluation metrics like precision, recall, and F1-score.

# %%
# Assuming X_val and y_val are your test inputs and labels, respectively.
# If you have a separate test set, replace X_val and y_val accordingly.

# Predict classes with the model
predictions = model.predict({"input_ids": input_ids_val, "attention_mask": attention_masks_val})
predicted_labels = np.argmax(predictions.logits, axis=1)

# Since your labels are already encoded with LabelEncoder, there's no need to decode them

# Generate the confusion matrix
cm = confusion_matrix(labels_val, predicted_labels)

# Calculate per-class accuracies
accuracies = cm.diagonal() / cm.sum(axis=1)

# Create an annotated confusion matrix with accuracies
cm_with_acc = cm.astype('str')  # Convert counts to string for annotation
for i in range(len(cm)):
    for j in range(len(cm[i])):
        # Append accuracy to the diagonal elements
        if i == j:
            cm_with_acc[i][j] = f"{cm[i][j]}\n({accuracies[i]*100:.1f}%)"
        else:
            cm_with_acc[i][j] += "\n "

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(cm, annot=cm_with_acc, fmt='', ax=ax, cmap='Blues', 
            xticklabels=label_encoder.classes_, 
            yticklabels=label_encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix with Accuracies')
plt.show()
# Out:
# 831/831 [==============================] - 192s 226ms/step

# %% [markdown]
# ## Prepare the Submission DataFrame and Save

# %%
# Load the test dataset
test_df = pd.read_csv('test (1).csv', sep='\t')

# Assuming 'sentence' is your column of interest and tokenizer is already defined
# Prepare the test sentences with RobertaTokenizer
test_input_ids = []
test_attention_masks = []

for sent in test_df['sentence']:
    encoded_dict = tokenizer.encode_plus(
                        sent,                        # Sentence to encode
                        add_special_tokens = True,   # Add '[CLS]' and '[SEP]'
                        max_length = 128,            # Pad & truncate all sentences
                        pad_to_max_length = True,
                        return_attention_mask = True,# Construct attention masks
                        return_tensors = 'tf',       # Return tf tensors
                   )
    
    # Add the encoded sentence to the list
    test_input_ids.append(encoded_dict['input_ids'])
    test_attention_masks.append(encoded_dict['attention_mask'])

# Convert lists into tensors
test_input_ids = tf.concat(test_input_ids, axis=0)
test_attention_masks = tf.concat(test_attention_masks, axis=0)

# Make predictions using the trained model
predictions = model.predict({"input_ids": test_input_ids, "attention_mask": test_attention_masks})
predicted_labels = np.argmax(predictions.logits, axis=1)

# Convert numeric predictions back to original labels using the LabelEncoder
predicted_emotions = label_encoder.inverse_transform(predicted_labels)

# Prepare the submission DataFrame
submission_df = pd.DataFrame({
    'id': test_df['id'],  # Assuming there's an 'id' column in your test set
    'emotion': predicted_emotions
})

# Save the submission file
submission_df.to_csv('Large_final.csv', index=False, sep=',')
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:2688: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 45/45 [==============================] - 10s 219ms/step

# %%
import joblib

# Define the base path for saving
base_save_path = "Large_final"

# Specify the paths for the model, tokenizer, and label encoder
model_save_path = f"{base_save_path}/model"
tokenizer_save_path = f"{base_save_path}/tokenizer"
label_encoder_save_path = f"{base_save_path}/label_encoder.joblib"

# Assuming `model` is your TFRobertaForSequenceClassification model,
# `tokenizer` is your RobertaTokenizer, and `label_encoder` is your LabelEncoder instance

# Save the model
model.save_pretrained(model_save_path)

# Save the tokenizer
tokenizer.save_pretrained(tokenizer_save_path)

# Save the label encoder
joblib.dump(label_encoder, label_encoder_save_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 15
#       9 label_encoder_save_path = f"{base_save_path}/label_encoder.joblib"
#      11 # Assuming `model` is your TFRobertaForSequenceClassification model,
#      12 # `tokenizer` is your RobertaTokenizer, and `label_encoder` is your LabelEncoder instance
#      13
#      14 # Save the model
# ---> 15 model.save_pretrained(model_save_path)
#      17 # Save the tokenizer
#      18 tokenizer.save_pretrained(tokenizer_save_path)
#
# File /usr/local/lib/python3.11/dist-packages/transformers/modeling_tf_utils.py:2438, in TFPreTrainedModel.save_pretrained(self, save_directory, saved_model, version, push_to_hub, signatures, max_shard_size, create_pr, safe_serialization, token, **kwargs)
#    2436         safe_save_file(state_dict, output_model_file, metadata={"format": "tf"})
#    2437     else:
# -> 2438         self.save_weights(output_model_file)
#    2439     logger.info(f"Model weights saved in {output_model_file}")
#    2440 else:
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3175, in Model.save_weights(self, filepath, overwrite, save_format, options)
#    3111 @traceback_utils.filter_traceback
#    3112 def save_weights(
#    3113     self, filepath, overwrite=True, save_format=None, options=None
#    3114 ):
#    3115     """Saves all layer weights.
#    3116
#    3117     Either saves in HDF5 or in TensorFlow format based on the `save_format`
#    (...)
#    3173             HDF5 format.
#    3174     """
# -> 3175     saving_api.save_weights(
#    3176         self,
#    3177         filepath=filepath,
#    3178         overwrite=overwrite,
#    3179         save_format=save_format,
#    3180         options=options,
#    3181     )
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py:284, in save_weights(model, filepath, overwrite, **kwargs)
#     282     saving_lib.save_weights_only(model, filepath)
#     283 else:
# --> 284     legacy_sm_saving_lib.save_weights(
#     285         model, filepath, overwrite=overwrite, **kwargs
#     286     )
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/saving/legacy/save.py:370, in save_weights(model, filepath, overwrite, save_format, options)
#     368 if save_format == "h5":
#     369     with h5py.File(filepath, "w") as f:
# --> 370         hdf5_format.save_weights_to_hdf5_group(f, model)
#     371 else:
#     372     if not tf.executing_eagerly():
#     373         # Call `get_session` to initialize any uninitialized variables.
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/saving/legacy/hdf5_format.py:757, in save_weights_to_hdf5_group(f, model)
#     755     g = f.create_group(layer.name)
#     756     weights = _legacy_weights(layer)
# --> 757     save_subset_weights_to_hdf5_group(g, weights)
#     758 weights = model._trainable_weights + model._non_trainable_weights
#     759 g = f.create_group("top_level_model_weights")
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/saving/legacy/hdf5_format.py:725, in save_subset_weights_to_hdf5_group(f, weights)
#     718 def save_subset_weights_to_hdf5_group(f, weights):
#     719     """Save top-level weights of a model to a HDF5 group.
#     720
#     721     Args:
#     722         f: HDF5 group.
#     723         weights: List of weight variables.
#     724     """
# --> 725     weight_values = backend.batch_get_value(weights)
#     726     weight_names = [w.name.encode("utf8") for w in weights]
#     727     save_attributes_to_hdf5_group(f, "weight_names", weight_names)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend.py:4248, in batch_get_value(tensors)
#    4236 """Returns the value of more than one tensor variable.
#    4237
#    4238 Args:
#    (...)
#    4245     RuntimeError: If this method is called inside defun.
#    4246 """
#    4247 if tf.executing_eagerly():
# -> 4248     return [x.numpy() for x in tensors]
#    4249 elif tf.inside_function():
#    4250     raise RuntimeError("Cannot get value inside Tensorflow graph function.")
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend.py:4248, in <listcomp>(.0)
#    4236 """Returns the value of more than one tensor variable.
#    4237
#    4238 Args:
#    (...)
#    4245     RuntimeError: If this method is called inside defun.
#    4246 """
#    4247 if tf.executing_eagerly():
# -> 4248     return [x.numpy() for x in tensors]
#    4249 elif tf.inside_function():
#    4250     raise RuntimeError("Cannot get value inside Tensorflow graph function.")
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 def numpy(self):
#     688   if context.executing_eagerly():
# --> 689     return self.read_value().numpy()
#     690   raise NotImplementedError(
#     691       "numpy() is only available when eager execution is enabled.")
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py:394, in _EagerTensorBase.numpy(self)
#     371 """Copy of the contents of this Tensor into a NumPy array or scalar.
#     372
#     373 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#     391     NumPy dtype.
#     392 """
#     393 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 394 maybe_arr = self._numpy()  # pylint: disable=protected-access
#     395 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py:360, in _EagerTensorBase._numpy(self)
#     358 def _numpy(self):
#     359   try:
# --> 360     return self._numpy_internal()
#     361   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     362     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
data_sub = 'Large_final.csv'

# Load the dataset
data_submission = pd.read_csv(data_sub)

# Define the mapping from integer labels to emotion names
emotion_mapping = {
    0: 'anger',
    1: 'disgust',
    2: 'fear',
    3: 'happiness',
    4: 'sadness',
    5: 'surprise'
}

# Apply the mapping to the 'emotion' column
data_submission['emotion'] = data_submission['emotion'].map(emotion_mapping)
# Save the submission file
data_submission.to_csv('Large_final.csv', index=False, sep=',')
